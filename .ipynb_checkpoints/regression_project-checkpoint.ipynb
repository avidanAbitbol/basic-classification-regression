# %% [markdown]
# ![c0e0984f-12e5-46d7-a1fc-c653ecd51ea0.jfif](attachment:c0e0984f-12e5-46d7-a1fc-c653ecd51ea0.jfif)

# %% [markdown]
# ## imports

# %%
#imports of the used library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.datasets import make_regression
from sklearn.linear_model import Ridge
import seaborn as seabornInstance
from sklearn.linear_model import LinearRegression
from sklearn.feature_extraction import DictVectorizer
from io import StringIO
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, cross_validate, StratifiedKFold, RandomizedSearchCV

# %% [markdown]
# ### load of the data

# %%
df = pd.read_csv('C:\matala 3\All_seasons.csv')

# %%
##Look at the inital Data 
df
# Out:
#        Unnamed: 0         player_name team_abbreviation   age  player_height  \
# 0               0       Dennis Rodman               CHI  36.0         198.12
# 1               1   Dwayne Schintzius               LAC  28.0         215.90
# 2               2        Earl Cureton               TOR  39.0         205.74
# 3               3         Ed O'Bannon               DAL  24.0         203.20
# 4               4         Ed Pinckney               MIA  34.0         205.74
# ...           ...                 ...               ...   ...            ...
# 11140       11140         Maxi Kleber               DAL  28.0         208.28
# 11141       11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142       11142      Meyers Leonard               MIA  28.0         213.36
# 11143       11143        Norvel Pelle               PHI  27.0         208.28
# 11144       11144         Matt Thomas               TOR  25.0         193.04
#
# ...

# %%
#showing the first 5 rows of the data
df.head()
# Out:
#    Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0           0      Dennis Rodman               CHI  36.0         198.12
# 1           1  Dwayne Schintzius               LAC  28.0         215.90
# 2           2       Earl Cureton               TOR  39.0         205.74
# 3           3        Ed O'Bannon               DAL  24.0         203.20
# 4           4        Ed Pinckney               MIA  34.0         205.74
#
#    player_weight                      college country draft_year draft_round  \
# 0      99.790240  Southeastern Oklahoma State     USA       1986           2
# 1     117.933920                      Florida     USA       1990           1
# 2      95.254320                Detroit Mercy     USA       1979           3
# 3     100.697424                         UCLA     USA       1995           1
# 4     108.862080                    Villanova     USA       1985           1
#
# ...

# %% [markdown]
# ### data information

# %%
#Data frame information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11145 entries, 0 to 11144
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         11145 non-null  int64
#  1   player_name        11145 non-null  object
#  2   team_abbreviation  11145 non-null  object
#  3   age                11145 non-null  float64
#  4   player_height      11145 non-null  float64
#  5   player_weight      11145 non-null  float64
#  6   college            11145 non-null  object
#  7   country            11145 non-null  object
#  8   draft_year         11145 non-null  object
#  9   draft_round        11145 non-null  object
#  10  draft_number       11145 non-null  object
#  11  gp                 11145 non-null  int64
#  12  pts                11145 non-null  float64
#  13  reb                11145 non-null  float64
#  14  ast                11145 non-null  float64
#  15  net_rating         11145 non-null  float64
# ...

# %%
# numeral information of the data frame 
df.describe().transpose()
# Out:
#                  count         mean          std         min        25%  \
# Unnamed: 0     11145.0  5572.000000  3217.428709    0.000000  2786.0000
# age            11145.0    27.168686     4.344164   18.000000    24.0000
# player_height  11145.0   200.812818     9.190973  160.020000   195.5800
# player_weight  11145.0   100.637868    12.576295   60.327736    90.7184
# gp             11145.0    52.005832    25.069495    1.000000    32.0000
# pts            11145.0     8.126487     5.935482    0.000000     3.5000
# reb            11145.0     3.560036     2.495394    0.000000     1.8000
# ast            11145.0     1.801463     1.789940    0.000000     0.6000
# net_rating     11145.0    -2.153899    12.150611 -200.000000    -6.3000
# oreb_pct       11145.0     0.055593     0.043889    0.000000     0.0220
# dreb_pct       11145.0     0.141772     0.063194    0.000000     0.0960
# usg_pct        11145.0     0.185599     0.053047    0.000000     0.1500
# ...

# %% [markdown]
# ## visualiztion

# %%
#Take a View of all features to gain insights
df.hist(figsize=(20,20));

# %%
#coraltion plot for Age and Salary
ax=sns.regplot(x='age',y='pts',data=df)

# %%
#the dsnsity of the players for age
plt.figure(figsize=(10,6))
sns.kdeplot(df['age'], shade=True)
plt.xlim((15,45))
plt.title("PMF of Players' Age")
plt.ylabel("Density")
plt.xlabel('Age')
plt.grid(True)
plt.show()

# %%
#the dsnsity of the players for points
plt.figure(figsize=(10,6))
sns.kdeplot(df['pts'], shade=True)
plt.xlim((0,45))
plt.title("PMF of Players points")
plt.ylabel("Density")
plt.xlabel('points')
plt.grid(True)
plt.show()

# %%
#some coraltion to learn the data for the coraltion with points feature
sns.pairplot(df, x_vars=['oreb_pct','player_height','player_weight','age'], y_vars='pts', height=7, aspect=0.7, kind='reg')

# %%
sns.pairplot(df, x_vars=['reb','ast','usg_pct','gp'], y_vars='pts', height=7, aspect=0.7, kind='reg')

# %% [markdown]
# ### Checking and Cleaning the data

# %%
#changing the data from categorial to numeral
rows = df.shape[0]

for row in range(1,rows):

    val = df.loc[row,'country']
    if val=='USA' :
        df.loc[row,'country'] = 0
    else :
        df.loc[row,'country'] = 1
df['country'].value_counts()
# Out:
# 0      9409
# 1      1735
# USA       1
# Name: country, dtype: int64

# %%
#changing the data from NaN to numeral by understanding which data need to be input
rows = df.shape[0]

for row in range(1,rows):

    val = df.loc[row,'draft_number']
    if val=='Undrafted' :
        df.loc[row,'draft_number'] = 100
    else :
        df.loc[row,'draft_number'] = df.loc[row,'draft_number']
        
for row in range(1,rows):

    val = df.loc[row,'draft_round']
    if val=='Undrafted' :
        df.loc[row,'draft_round'] = 3
    else :
        df.loc[row,'draft_round'] = df.loc[row,'draft_round']

# %%
#dropping wide data that not helping to find what we search,features like name,index or college name
df.drop(['Unnamed: 0','player_name','team_abbreviation','college','draft_year','season'], inplace = True, axis = 1)

# %%
df.drop(df.index[0],inplace=True)

# %%
#Heatmap of all features.
cor = df.corr()
fig, ax = plt.subplots(figsize=(30,30))
sns.heatmap(cor, annot = True)

# %%
#checkin for other NaN
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Explanation of the relevant features

# %% [markdown]
# age - player age
# player height
# player weight
# gp - games played
# pts - average of points per game
# reb- average of rebounds per game
# ast- average of asists per game
# ast_pct - precentege of asists
# MIN = Minutes
# ts_pct = Field-goals attempted
# OREB =precentege of Offensive rebounds
# DREB = precentege of Defensive rebounds
# REB = average of  rebounds

# %% [markdown]
# # machine learning model

# %% [markdown]
# # Linear regression

# %% [markdown]
# ![understanding_of_linear_regression_with_python_1.png](attachment:understanding_of_linear_regression_with_python_1.png)

# %% [markdown]
# ### scaling the data

# %%
#Standardize features by removing the mean and scaling to unit variance
#StandardScaler Reducing each columns to gauss
scale = StandardScaler()
dfxy = pd.DataFrame(scale.fit_transform(df.values), columns=df.columns, index=df.index)

# %%
# spliting the data 
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.25, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-36639be47d65> in <module>
#       1 # spliting the data
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.25, random_state=42)
#
# NameError: name 'x' is not defined

# %%
#checking the results of the scaling and define the vectors
x= dfxy.drop(columns=['pts'])
y = dfxy.iloc[:, 7]
print(x)

# %%
print(y)

# %%
#the size of the train data
print(x_train.shape)
print(y_train.shape)

# %%
#the size of the test data
print(x_test.shape)
print(y_test.shape)

# %% [markdown]
# ### define the model

# %%
linreg=LinearRegression(fit_intercept = True)
reg=linreg.fit(x_train, y_train)
reg_predict = reg.predict(X_test)

# %%
#the inital score 
reg.score(x_train, y_train)

# %%
y_pred=reg.predict(x_test)
y_test=np.array(y_test)
dnormalized_pred=(y_pred)*(y.std())+(y.mean())
dnormalized_test=(y_test)*(y.std())+(y.mean())
delta_y=dnormalized_pred-dnormalized_test
print(delta_y)

# %% [markdown]
# ### a plot that show the variance of the prediction on the line

# %%
plt.plot(dnormalized_test, dnormalized_pred, 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(dnormalized_test, dnormalized_pred, 1)

#add linear regression line to scatterplot 
plt.plot(dnormalized_test, m*dnormalized_test+b)

# %%
print("R2 Score:",reg.score(x_test,y_test))
print("Mean Square ERR:",mean_squared_error(y_test,reg_predict, squared=False))

# %% [markdown]
# ### cross validation to train the model

# %%
reg_scores = cross_val_score(LinearRegression(),x_train, y_train,cv=5,scoring="neg_mean_squared_error", )
reg_scores_r2 = cross_val_score(LinearRegression(),x_train, y_train,cv=5,scoring="r2")

#print(linear_reg_scores)
#print(linear_reg_scores_r2)

print("After cross validation:\n")
print("R2 Score:",reg_scores_r2.mean())
print ("Mean Square ERR:",np.sqrt(-reg_scores.mean()))

# %% [markdown]
# ### the score is higher than before but not enough to me

# %% [markdown]
# ## dummy regressor model

# %%
#dummy regressor to check if the model is really better than a dummy model
dummy_regr_median = DummyRegressor(strategy="median")
dummy_regr_median.fit(x_train, y_train)
y_pred = dummy_regr_median.predict(x_test)
err_dummy_meadian = mean_squared_error(y_test,dummy_regr_median.predict(x_test), squared=False)
initial_prediction_dm_median = dummy_regr_median.predict(X_test)

print("R2 Score:",metrics.r2_score(y_test, y_pred))
print ("Mean Square ERR:",mean_squared_error(y_test,dummy_regr_median.predict(x_test), squared=False))

# %% [markdown]
# # random forest model

# %%
#define the random forest regressor as a model
random_forest = RandomForestRegressor() 
random_forest.fit(x_train, y_train)
y_pred = random_forest.predict(x_test)

# %% [markdown]
# ### grid search model to find the best parameters for this model

# %% [markdown]
# ### n_estimators = number of trees in the foreset
# ### max_features = max number of features considered for splitting a node
# ### max_depth = max number of levels in each decision tree
# ### min_samples_split = min number of data points placed in a node before the node is split
# ### min_samples_split = min number of data points placed in a node before the node is split
# ### min_samples_leaf = min number of data points allowed in a leaf node

# %%
random_forest_tuning = RandomForestRegressor()
param_grid = {
   'n_estimators': [100, 200, 500],
   'max_features': ['auto', 'sqrt', 'log2'],
   'max_depth' : [4,5,6,7,8],
}
GSCV = GridSearchCV(estimator=random_forest_tuning, param_grid=param_grid, cv=5)
GSCV.fit(x_train, y_train)
GSCV.best_params_

# %% [markdown]
# ### mean squared error is much better

# %%
y_pred = GSCV.predict(x_test)
print('MSE: ', mean_squared_error(y_test, y_pred))

# %%
GSCV.score(x_test,y_test)

# %% [markdown]
# ### the score now is higher from the linear regressor

# %%
y_pred_final=GSCV.predict(x_test)
y_test=np.array(y_test)
dnormalized_pred_final=(y_pred_final)*(y.std())+(y.mean())
dnormalized_test=(y_test)*(y.std())+(y.mean())
delta_y=dnormalized_pred_final-dnormalized_test

# %% [markdown]
# ### we can see the changes in the plot

# %%
plt.plot(dnormalized_test, dnormalized_pred_final, 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(dnormalized_test, dnormalized_pred_final, 1)

#add linear regression line to scatterplot 
plt.plot(dnormalized_test, m*dnormalized_test+b)

# %% [markdown]
# ## we can see that the random forrest is slightly better than the linear regressor classifier, that is why i chose it as the best model for to find the average of points
