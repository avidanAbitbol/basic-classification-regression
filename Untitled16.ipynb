# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
df = pd.read_csv('C:\matala 3\All_seasons.csv')

# %%
df
# Out:
#        Unnamed: 0         player_name team_abbreviation   age  player_height  \
# 0               0       Dennis Rodman               CHI  36.0         198.12
# 1               1   Dwayne Schintzius               LAC  28.0         215.90
# 2               2        Earl Cureton               TOR  39.0         205.74
# 3               3         Ed O'Bannon               DAL  24.0         203.20
# 4               4         Ed Pinckney               MIA  34.0         205.74
# ...           ...                 ...               ...   ...            ...
# 11140       11140         Maxi Kleber               DAL  28.0         208.28
# 11141       11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142       11142      Meyers Leonard               MIA  28.0         213.36
# 11143       11143        Norvel Pelle               PHI  27.0         208.28
# 11144       11144         Matt Thomas               TOR  25.0         193.04
#
#        player_weight                      college  country draft_year  \
# 0          99.790240  Southeastern Oklahoma State      USA       1986
# 1         117.933920                      Florida      USA       1990
# 2          95.254320                Detroit Mercy      USA       1979
# 3         100.697424                         UCLA      USA       1995
# 4         108.862080                    Villanova      USA       1985
# ...              ...                          ...      ...        ...
# 11140     108.862080                         None  Germany  Undrafted
# 11141      97.522280                       Tulane      USA       2018
# 11142     117.933920                     Illinois      USA       2012
# 11143     104.779752                         None      USA  Undrafted
# 11144      86.182480                   Iowa State      USA  Undrafted
#
#       draft_round  ...  pts   reb  ast  net_rating  oreb_pct  dreb_pct  \
# 0               2  ...  5.7  16.1  3.1        16.1     0.186     0.323
# 1               1  ...  2.3   1.5  0.3        12.3     0.078     0.151
# 2               3  ...  0.8   1.0  0.4        -2.1     0.105     0.102
# 3               1  ...  3.7   2.3  0.6        -8.7     0.060     0.149
# 4               1  ...  2.4   2.4  0.2       -11.2     0.109     0.179
# ...           ...  ...  ...   ...  ...         ...       ...       ...
# 11140   Undrafted  ...  9.1   5.4  1.1         4.6     0.056     0.140
# 11141           2  ...  1.2   0.3  0.1        -2.4     0.018     0.058
# 11142           1  ...  6.1   5.1  1.1         5.6     0.029     0.217
# 11143   Undrafted  ...  2.1   3.0  0.4       -16.4     0.085     0.237
# 11144   Undrafted  ...  4.5   1.4  0.5         1.0     0.017     0.104
#
#        usg_pct  ts_pct  ast_pct   season
# 0        0.100   0.479    0.113  1996-97
# 1        0.175   0.430    0.048  1996-97
# 2        0.103   0.376    0.148  1996-97
# 3        0.167   0.399    0.077  1996-97
# 4        0.127   0.611    0.040  1996-97
# ...        ...     ...      ...      ...
# 11140    0.136   0.605    0.064  2019-20
# 11141    0.164   0.480    0.033  2019-20
# 11142    0.120   0.640    0.076  2019-20
# 11143    0.126   0.521    0.056  2019-20
# 11144    0.149   0.663    0.089  2019-20
#
# [11145 rows x 22 columns]

# %%
df.drop(['Unnamed: 0','player_name','team_abbreviation','college','country','draft_year','draft_round','draft_number','season'], inplace = True, axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11145 entries, 0 to 11144
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            11145 non-null  float64
#  1   player_height  11145 non-null  float64
#  2   player_weight  11145 non-null  float64
#  3   gp             11145 non-null  int64
#  4   pts            11145 non-null  float64
#  5   reb            11145 non-null  float64
#  6   ast            11145 non-null  float64
#  7   net_rating     11145 non-null  float64
#  8   oreb_pct       11145 non-null  float64
#  9   dreb_pct       11145 non-null  float64
#  10  usg_pct        11145 non-null  float64
#  11  ts_pct         11145 non-null  float64
#  12  ast_pct        11145 non-null  float64
# dtypes: float64(12), int64(1)
# memory usage: 1.1 MB

# %%
df.describe().transpose()
# Out:
#                  count        mean        std         min       25%  \
# age            11145.0   27.168686   4.344164   18.000000   24.0000
# player_height  11145.0  200.812818   9.190973  160.020000  195.5800
# player_weight  11145.0  100.637868  12.576295   60.327736   90.7184
# gp             11145.0   52.005832  25.069495    1.000000   32.0000
# pts            11145.0    8.126487   5.935482    0.000000    3.5000
# reb            11145.0    3.560036   2.495394    0.000000    1.8000
# ast            11145.0    1.801463   1.789940    0.000000    0.6000
# net_rating     11145.0   -2.153899  12.150611 -200.000000   -6.3000
# oreb_pct       11145.0    0.055593   0.043889    0.000000    0.0220
# dreb_pct       11145.0    0.141772   0.063194    0.000000    0.0960
# usg_pct        11145.0    0.185599   0.053047    0.000000    0.1500
# ts_pct         11145.0    0.508099   0.098879    0.000000    0.4780
# ast_pct        11145.0    0.131078   0.095017    0.000000    0.0650
#
#                      50%         75%        max
# age             27.00000   30.000000   44.00000
# player_height  200.66000  208.280000  231.14000
# player_weight   99.79024  109.315672  163.29312
# gp              58.00000   74.000000   85.00000
# pts              6.60000   11.500000   36.10000
# reb              3.00000    4.700000   16.30000
# ast              1.20000    2.400000   11.70000
# net_rating      -1.30000    3.200000  300.00000
# oreb_pct         0.04300    0.086000    1.00000
# dreb_pct         0.13200    0.182000    1.00000
# usg_pct          0.18200    0.218000    1.00000
# ts_pct           0.52100    0.557000    1.50000
# ast_pct          0.10200    0.178000    1.00000

# %%
df
# Out:
#         age  player_height  player_weight  gp  pts   reb  ast  net_rating  \
# 0      36.0         198.12      99.790240  55  5.7  16.1  3.1        16.1
# 1      28.0         215.90     117.933920  15  2.3   1.5  0.3        12.3
# 2      39.0         205.74      95.254320   9  0.8   1.0  0.4        -2.1
# 3      24.0         203.20     100.697424  64  3.7   2.3  0.6        -8.7
# 4      34.0         205.74     108.862080  27  2.4   2.4  0.2       -11.2
# ...     ...            ...            ...  ..  ...   ...  ...         ...
# 11140  28.0         208.28     108.862080  63  9.1   5.4  1.1         4.6
# 11141  23.0         195.58      97.522280  15  1.2   0.3  0.1        -2.4
# 11142  28.0         213.36     117.933920  49  6.1   5.1  1.1         5.6
# 11143  27.0         208.28     104.779752  20  2.1   3.0  0.4       -16.4
# 11144  25.0         193.04      86.182480  31  4.5   1.4  0.5         1.0
#
#        oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct
# 0         0.186     0.323    0.100   0.479    0.113
# 1         0.078     0.151    0.175   0.430    0.048
# 2         0.105     0.102    0.103   0.376    0.148
# 3         0.060     0.149    0.167   0.399    0.077
# 4         0.109     0.179    0.127   0.611    0.040
# ...         ...       ...      ...     ...      ...
# 11140     0.056     0.140    0.136   0.605    0.064
# 11141     0.018     0.058    0.164   0.480    0.033
# 11142     0.029     0.217    0.120   0.640    0.076
# 11143     0.085     0.237    0.126   0.521    0.056
# 11144     0.017     0.104    0.149   0.663    0.089
#
# [11145 rows x 13 columns]

# %%
df.hist(figsize=(20,20));

# %%
# Out:
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\avida\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
cor = df.corr()
fig, ax = plt.subplots(figsize=(30,30))
sns.heatmap(cor, annot = True)

# %%
X_normal= df.drop(columns=['pts'])
Y_normal = df.iloc[:, 4]
print(X_normal)
# Out:
#         age  player_height  player_weight  gp   reb  ast  net_rating  \
# 0      36.0         198.12      99.790240  55  16.1  3.1        16.1
# 1      28.0         215.90     117.933920  15   1.5  0.3        12.3
# 2      39.0         205.74      95.254320   9   1.0  0.4        -2.1
# 3      24.0         203.20     100.697424  64   2.3  0.6        -8.7
# 4      34.0         205.74     108.862080  27   2.4  0.2       -11.2
# ...     ...            ...            ...  ..   ...  ...         ...
# 11140  28.0         208.28     108.862080  63   5.4  1.1         4.6
# 11141  23.0         195.58      97.522280  15   0.3  0.1        -2.4
# 11142  28.0         213.36     117.933920  49   5.1  1.1         5.6
# 11143  27.0         208.28     104.779752  20   3.0  0.4       -16.4
# 11144  25.0         193.04      86.182480  31   1.4  0.5         1.0
#
#        oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct
# 0         0.186     0.323    0.100   0.479    0.113
# 1         0.078     0.151    0.175   0.430    0.048
# 2         0.105     0.102    0.103   0.376    0.148
# 3         0.060     0.149    0.167   0.399    0.077
# 4         0.109     0.179    0.127   0.611    0.040
# ...         ...       ...      ...     ...      ...
# 11140     0.056     0.140    0.136   0.605    0.064
# 11141     0.018     0.058    0.164   0.480    0.033
# 11142     0.029     0.217    0.120   0.640    0.076
# 11143     0.085     0.237    0.126   0.521    0.056
# 11144     0.017     0.104    0.149   0.663    0.089
#
# [11145 rows x 12 columns]

# %%
print(Y_normal)
# Out:
# 0        5.7
# 1        2.3
# 2        0.8
# 3        3.7
# 4        2.4
#         ...
# 11140    9.1
# 11141    1.2
# 11142    6.1
# 11143    2.1
# 11144    4.5
# Name: pts, Length: 11145, dtype: float64

# %%
dfxy = pd.DataFrame(scale.fit_transform(df.values), columns=df.columns, index=df.index)

# %%
x_scale= dfxy.drop(columns=['pts'])
y_scale = dfxy.iloc[:, 4]
print(x_scale)
# Out:
#             age  player_height  player_weight        gp       reb       ast  \
# 0      2.033006      -0.292998      -0.067402  0.119440  5.025470  0.725497
# 1      0.191372       1.641595       1.375352 -1.476196 -0.825572 -0.838872
# 2      2.723619       0.536113      -0.428090 -1.715542 -1.025951 -0.783001
# 3     -0.729445       0.259743       0.004736  0.478458 -0.504967 -0.671261
# 4      1.572598       0.536113       0.653975 -0.997505 -0.464892 -0.894742
# ...         ...            ...            ...       ...       ...       ...
# 11140  0.191372       0.812484       0.653975  0.438567  0.737377 -0.391909
# 11141 -0.959649      -0.569369      -0.247746 -1.476196 -1.306480 -0.950612
# 11142  0.191372       1.365225       1.375352 -0.119905  0.617150 -0.391909
# 11143 -0.038832       0.812484       0.329355 -1.276742 -0.224438 -0.783001
# 11144 -0.499241      -0.845739      -1.149467 -0.837942 -0.865648 -0.727131
#
#        net_rating  oreb_pct  dreb_pct   usg_pct    ts_pct   ast_pct
# 0        1.502370  2.971452  2.867924 -1.613728 -0.294306 -0.190264
# 1        1.189615  0.510564  0.146034 -0.199814 -0.789883 -0.874381
# 2        0.004436  1.125786 -0.629388 -1.557171 -1.336030  0.178107
# 3       -0.538771  0.100416  0.114384 -0.350632 -1.103412 -0.569160
# 4       -0.744531  1.216930  0.589132 -1.104719  1.040719 -0.958580
# ...           ...       ...       ...       ...       ...       ...
# 11140    0.555873  0.009272 -0.028040 -0.935049  0.980036 -0.705983
# 11141   -0.020255 -0.856596 -1.325686 -0.407188 -0.284192 -1.032255
# 11142    0.638177 -0.605950  1.190480 -1.236684  1.334020 -0.579685
# 11143   -1.172512  0.670066  1.506979 -1.123571  0.130475 -0.790182
# 11144    0.259579 -0.879382 -0.597738 -0.689971  1.566638 -0.442861
#
# [11145 rows x 12 columns]

# %%
print(y_scale)
# Out:
# 0       -0.408829
# 1       -0.981681
# 2       -1.234410
# 3       -0.745801
# 4       -0.964832
#            ...
# 11140    0.164023
# 11141   -1.167015
# 11142   -0.341434
# 11143   -1.015378
# 11144   -0.611012
# Name: pts, Length: 11145, dtype: float64

# %%
sns.pairplot(df, x_vars=['reb','ast','usg_pct','gp'], y_vars='pts', height=7, aspect=0.7, kind='reg')

# %%
print(type(X))
print(X.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (11145, 12)

# %%
print(type(Y))
print(Y.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (11145,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_normal, Y_normal,test_size=0.25, random_state=42)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scale, y_scale,test_size=0.25, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (8358, 12)
# (8358,)
# (2787, 12)
# (2787,)

# %%
reg=linreg.fit(X_train, Y_train)
reg1=linreg.fit(x_train,y_train)

# %%
reg.score(X_train, Y_train)
# Out:
# 0.5123113491211658

# %%
reg.score(x_train, y_train)
# Out:
# 0.8734913969190383

# %%
reg.score(X_test, Y_test)
# Out:
# 0.4977298346610659

# %%
y_pred=reg.predict(x_test)
y_test=np.array(y_test)
dnormalized_pred=(y_pred)*(Y_normal.std())+(Y_normal.mean())
dnormalized_test=(y_test)*(Y_normal.std())+(Y_normal.mean())
delta_y=dnormalized_pred-dnormalized_test
print(delta_y)
# Out:
# [ 0.17231679  1.85035934 -0.4632949  ...  1.25848292  1.06436319
#  -0.43690055]

# %%
plt.scatter(dnormalized_test, delta_y)

# %%
print(reg.intercept_)
print(reg.coef_)
# Out:
# -0.0014780904569061185
# [-0.00147357  0.0141938  -0.00176693  0.06477799  0.52168325  0.4686215
#   0.02735543 -0.17546246 -0.17350536  0.37743605  0.0862566  -0.27416591]

# %%
list(zip(x, reg.coef_))
# Out:
# [('age', -0.0014735675541173363),
#  ('player_height', 0.014193795961919012),
#  ('player_weight', -0.001766930103048503),
#  ('gp', 0.06477798907270783),
#  ('reb', 0.5216832514556233),
#  ('ast', 0.4686214997236446),
#  ('net_rating', 0.02735542955226261),
#  ('oreb_pct', -0.1754624617114575),
#  ('dreb_pct', -0.17350535553228366),
#  ('usg_pct', 0.37743605266228214),
#  ('ts_pct', 0.08625660405344791),
#  ('ast_pct', -0.2741659147598626)]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('square root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.2370230695322702
# Mean Squared Error: 0.13536097900218017
# square root Mean Squared Error: 0.3679143636801643

# %%
dm = DummyRegressor(strategy="mean")
dm.fit(X_train, y_train)
y_predm =dm.predict(X_test)
print("Mean Squared Error of dummy: {}".format(metrics.mean_squared_error(y_test,dm.predict(X_test), squared=False)))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_predm))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_predm))
# Out:
# Mean Squared Error of dummy: 1.0065600455915562
# Mean Absolute Error: 0.7915030338367228
# Mean Squared Error: 1.0131631253812758
